# %%
import pandas as pd
df=pd.read_csv("StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
import seaborn as sns
sns.stripplot(data=df, y="writing score", x="math score", jitter=True)
# Out:
# <Axes: xlabel='math score', ylabel='writing score'>

# %%
import matplotlib.pyplot as plt
fig,ax=plt.subplots()
sns.stripplot(data=df, y="writing score", x="math score", jitter=True)
ax.axes.xaxis.set_ticks([])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig,ax=plt.subplots()
sns.stripplot(data=df, y="writing score", x="race/ethnicity", jitter=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Diagrama de enjambre
sns.swarmplot(data=df,y="writing score",x="race/ethnicity")
# Out:
# C:\Users\usuario\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 11.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\usuario\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 8.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='race/ethnicity', ylabel='writing score'>
# C:\Users\usuario\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 17.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\usuario\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 11.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#Diagrama de caja
sns.boxplot(data=df,y="writing score",x="race/ethnicity",palette="Set1")
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2700\4170902187.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,y="writing score",x="race/ethnicity",palette="Set1")
# <Axes: xlabel='race/ethnicity', ylabel='writing score'>

# %%
#Grafico de violin
sns.violinplot(data=df,y="writing score",x="race/ethnicity",palette="Set1")
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2700\3385923379.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df,y="writing score",x="race/ethnicity",palette="Set1")
# <Axes: xlabel='race/ethnicity', ylabel='writing score'>

# %%
#creación de lvplot
sns.catplot(data=df,y="writing score",x="race/ethnicity",palette="Set1",kind="boxen")
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2700\3392799887.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(data=df,y="writing score",x="race/ethnicity",palette="Set1",kind="boxen")

# %%
#creación de barplot
sns.barplot(data=df,y="writing score",x="race/ethnicity",palette="Set1")
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2700\2923071037.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df,y="writing score",x="race/ethnicity",palette="Set1")
# <Axes: xlabel='race/ethnicity', ylabel='writing score'>

# %%
#creación de barplot
sns.barplot(data=df,y="writing score",x="race/ethnicity",palette="Set1",hue="lunch")
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='writing score'>

# %%
#creación de pointplot
sns.pointplot(data=df,y="writing score",x="race/ethnicity",palette="Set1",hue="lunch")
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='writing score'>

# %%
#creación de countplot
sns.countplot(data=df,y="race/ethnicity",palette="Set1",hue="lunch")
# Out:
# <Axes: xlabel='count', ylabel='race/ethnicity'>

# %%
#creación de grafico de regresión
sns.regplot(data=df,y="writing score",x="reading score",marker="+")
# Out:
# <Axes: xlabel='reading score', ylabel='writing score'>

# %%
#creación de residuos
sns.residplot(data=df,y="writing score",x="reading score")
# Out:
# <Axes: xlabel='reading score', ylabel='writing score'>

# %%
import numpy as np
#creación de grafico de regresión y media por valor dex
sns.regplot(data=df,y="writing score",x="reading score",x_estimator=np.mean)
# Out:
# <Axes: xlabel='reading score', ylabel='writing score'>

# %%
df_withoutString = df.drop(['gender', 'race/ethnicity', 'parental level of education', 'lunch', 'test preparation course'], axis=1)
sns.heatmap(df_withoutString.corr())
# Out:
# <Axes: >

# %%
sns.heatmap(df_withoutString.corr(),annot=True)
# Out:
# <Axes: >

# %%
#Creación de tabla cruzada
pd.crosstab(df["gender"],df["race/ethnicity"],values=df["math score"],aggfunc="mean")
# Out:
# race/ethnicity    group A    group B    group C    group D    group E
# gender
# female          58.527778  61.403846  62.033333  65.248062  70.811594
# male            63.735849  65.930233  67.611511  69.413534  76.746479

# %%
pivot_table = pd.pivot_table(df, 
                              values="math score", 
                              index="gender", 
                              columns="race/ethnicity", 
                              aggfunc="mean")

# Crear el heatmap
sns.heatmap(pivot_table, annot=True, cmap="YlGnBu")
plt.title("Promedio de Math Score por Género y Grupo Étnico")
plt.show()
