# %%
import pandas as pd
df=pd.read_csv("StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
import seaborn as sns
for style in ["dark","whitegrid","darkgrid","ticks"]:
    sns.set_style(style)
    sns.displot(df["reading score"])

# %%
#Remover ejes
sns.set_style("ticks")
sns.displot(df["reading score"],kde=True)
sns.despine(left=True,bottom=True)

# %%
#Combinación de parámetros con Matplotlib
import matplotlib.pyplot as plt

fig,ax=plt.subplots()
sns.distplot(df["writing score"],ax=ax)
ax.set(xlabel="Writing Score", ylabel="Frecuencia relativa",title="Writing Score")
ax.set_title("Writing Score")
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_19868\4216759888.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["writing score"],ax=ax)
# Text(0.5, 1.0, 'Writing Score')

# %%
#Truncamiento de escala de visualización
fig,ax=plt.subplots()
sns.distplot(df["writing score"],ax=ax)
ax.set(xlabel="Writing Score", ylabel="Frecuencia relativa",xlim=(0,90),title="Writing Score")
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_19868\1930481528.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["writing score"],ax=ax)
# [Text(0.5, 0, 'Writing Score'),
#  Text(0, 0.5, 'Frecuencia relativa'),
#  (0.0, 90.0),
#  Text(0.5, 1.0, 'Writing Score')]

# %%
fig,(ax0,ax1)=plt.subplots(nrows=1,ncols=2,sharey=True)
sns.distplot(df["writing score"],ax=ax0) #Histograma para todas las observaciones
sns.distplot(df.query('gender == "male"')["writing score"], ax=ax1)#Histograma para los hombres
ax0.set(xlabel="Puntaje general de escritura",ylabel="Frecuencia")
ax1.set(xlabel="Puntaje de escritura para hombres",ylabel="Frecuencia")
ax1.axvline(x=75,label="Objetivo",linestyle="--")
ax1.legend()
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_19868\2440012929.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["writing score"],ax=ax0) #Histograma para todas las observaciones
# C:\Users\usuario\AppData\Local\Temp\ipykernel_19868\2440012929.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.query('gender == "male"')["writing score"], ax=ax1)#Histograma para los hombres

# %%
#Asignación de colores al histograma
paleta=["deep","muted","pastel","bright","dark","colorblind"]
for p in paleta:
    sns.set_palette(p)
    sns.displot(df["reading score"],kde=True)
